# %%
import pandas as pd
import json

# %%
skytrain_df = pd.read_csv("rapid-transit-stations.csv",sep=";")

# %%
def parse_coordinates(s):
    # Convert to JSON object
    json_obj = json.loads(s)
    #return it coordinates
    return json_obj["coordinates"]

# %%
# Parse coordinates
skytrain_df['Geom'] = skytrain_df['Geom'].apply(parse_coordinates)
# Get latitude
skytrain_df['lon'] = skytrain_df['Geom'].apply(lambda x: x[0])
skytrain_df['lat'] = skytrain_df['Geom'].apply(lambda x: x[1])
# Keep necessary columns
skytrain_df = skytrain_df[["STATION","lat","lon"]]
skytrain_df
# Out:
#                      STATION        lat         lon
# 0               MARINE DRIVE  49.209548 -123.117071
# 1                VCC - CLARK  49.265783 -123.078962
# 2                    NANAIMO  49.248272 -123.055872
# 3   MAIN ST. - SCIENCE WORLD  49.273178 -123.100607
# 4        STADIUM - CHINATOWN  49.279442 -123.109565
# 5                  GRANVILLE  49.283638 -123.116404
# 6                    BURRARD  49.285860 -123.119972
# 7                 WATERFRONT  49.286075 -123.111738
# 8                KING EDWARD  49.249123 -123.115336
# 9       BROADWAY-\nCITY HALL  49.262773 -123.114782
# 10                    RUPERT  49.260765 -123.032824
# 11       JOYCE - COLLINGWOOD  49.238394 -123.031807
# 12     OAKRIDGE-\n41st. AVE.  49.233467 -123.116041
# 13          COMMERCIAL DRIVE  49.262936 -123.068454
# 14                   RENFREW  49.258893 -123.045308
# 15               29TH AVENUE  49.244243 -123.045941
# 16                  BROADWAY  49.261818 -123.069099
# 17       LANGARA-\n49th AVE.  49.226387 -123.116325
# 18          OLYMPIC\nVILLAGE  49.266340 -123.115197
# 19     YALETOWN-/nROUNDHOUSE  49.274362 -123.121890
# 20   VANCOUVER\nCITY\nCENTRE  49.281735 -123.119284
# 21                WATERFRONT  49.285666 -123.113339

# %%
skytrain_df.to_csv("processed_skytrain_data.csv",index=None)
